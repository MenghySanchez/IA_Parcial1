# %%
#librerias
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# %%
#Universo de discurso para la luz exterior
luz = np.linspace(0,100)
#====================================================
#Funcion de pertenencia para la luz exterior
LBaja = fuzz.trapmf(luz,[-30.24, -9.76, 9.76, 30.24])
LAmbiente = fuzz.trimf(luz, (10, 50, 90))
LAlta = fuzz.trapmf(luz, (70, 85, 100, 100))
#====================================================
#Grafica de luz externa
plt.plot(luz, LBaja, label="Luz Baja")
plt.plot(luz, LAmbiente, label="Luz Ambiente")
plt.plot(luz, LAlta, label="Luz Alta")
plt.legend(loc='best')
plt.xlabel('Rango')
plt.ylabel('intervalo')
plt.show()

# %%
#Universo de discurso para la temperatura
temp = np.linspace(0,100)
#====================================================
#Funcion de pertenencia para la temperatura
TFria = fuzz.trapmf(temp,[-26.1, -4.56, 8.98, 19.97])
TAmbiente = fuzz.trimf(temp, (16, 28, 40))
TCaliente = fuzz.trapmf(temp, (35, 50, 100, 100))
#====================================================
#Grafica de Temperatura
plt.plot(temp, TFria, label="Frio")
plt.plot(luz, TAmbiente, label="Temp Ambiente")
plt.plot(luz, TCaliente, label="Caliente")
plt.legend(loc='best')
plt.xlabel('Rango')
plt.ylabel('Intervalo')
plt.show()
